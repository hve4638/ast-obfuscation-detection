# %%
# 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sys
sys.setrecursionlimit(1000000)

# %%
# 이 부분만 변경
Path = '/content/drive/MyDrive/Colab Notebooks/캡스톤디자인/csv/rc_powershell/'
sPath = '/content/drive/MyDrive/Colab Notebooks/캡스톤디자인/extracted(60)/rc_powershell/'
dir_name = 'rc_powershell_'
r = list(range(460))

# ast 60
ast_list_60 = ['ConstantExpressionAst','VariableExpressionAst','StringConstantExpressionAst','PipelineAst','CommandExpressionAst','BinaryExpressionAst','CommandAst','MemberExpressionAst','InvokeMemberExpressionAst','CommandParameterAst','StatementBlockAst','AssignmentStatementAst','ParenExpressionAst','TypeConstraintAst','TypeExpressionAst','ParameterAst','NamedBlockAst','ScriptBlockAst','ArrayLiteralAst','SubExpressionAst','IfStatementAst','ExpandableStringExpressionAst','ConvertExpressionAst','ScriptBlockExpressionAst','NamedAttributeArgumentAst','IndexExpressionAst','AttributeAst','ArrayExpressionAst','UnaryExpressionAst','FunctionDefinitionAst','HashtableAst','ParamBlockAst','ForEachStatementAst','ReturnStatementAst','TryStatementAst','CatchClauseAst','ErrorExpressionAst','ThrowStatementAst','BreakStatementAst','WhileStatementAst','SwitchStatementAst','ExitStatementAst','ContinueStatementAst','FileRedirectionAst','ForStatementAst','ErrorStatementAst','TrapStatementAst','DynamicKeywordStatementAst','AttributedExpressionAst','DoWhileStatementAst','ConfigurationDefinitionAst','MergingRedirectionAst','UsingExpressionAst','DoUntilStatementAst','BlockStatementAst','PropertyMemberAst','FunctionMemberAst','TypeDefinitionAst','UsingStatementAst','DataStatementAst']
# ast importance
#ast_list_imp = ['CommandExpressionAst', 'VariableExpressionAst', 'ArrayExpressionAst', 'ScriptBlockAst', 'ArrayLiteralAst', 'NamedBlockAst', 'MemberExpressionAst', 'PipelineAst', 'BinaryExpressionAst', 'CommandAst', 'AssignmentStatementAst', 'StringConstantExpressionAst', 'InvokeMemberExpressionAst']

# %%
def cnt (type, parent, i, depth):
  print(i, type,parent)
  # type과 parent가 모두 해당하는 경우
  if (parent in ast_list) and (i < len(data.index.values)-1):
    if type in ast_list:
      df.loc[type, parent] += 1
      cnt (data.loc[i+1, 'Type'], data.loc[i+1, 'Parent'], i+1, data.loc[i+1, 'Depth'])
  # parent만 존재하고 type은 존재하지 않는 경우
    # 리프 노드가 아니면
    elif (i < len(data.index.values)-1) and (depth <= data.loc[i+1, 'Depth']):
      cnt (data.loc[i+1, 'Type'], parent, i+1, data.loc[i+1, 'Depth'])
  elif (i < len(data.index.values)-1):
    cnt (data.loc[i+1, 'Type'], data.loc[i+1, 'Parent'], i+1, data.loc[i+1, 'Depth'])

# %%
def cnt_0 ():
  type = data.loc[0,'Type']
  parent = data.loc[0,'Parent']
  depth = data.loc[0,'Depth']
  for i in range(len(data.index.values)-1):
    # type과 parent가 모두 해당하는 경우
    if (type in ast_list) and (parent in ast_list):
      df.loc[type, parent] += 1
      type = data.loc[i+1, 'Type']
      parent = data.loc[i+1, 'Parent']
      depth = data.loc[i+1, 'Depth']
    # parent만 존재하는 경우
    # 리프 노드가 아니면
    elif (parent in ast_list) and (float(depth) <= float(data.loc[i+1, 'Depth'])):
      type = data.loc[i+1, 'Type']
      depth = data.loc[i+1, 'Depth']
    else:
      type = data.loc[i+1, 'Type']
      parent = data.loc[i+1, 'Parent']
      depth = data.loc[i+1, 'Depth']
  if (type in ast_list) and (parent in ast_list):
    df.loc[type, parent] += 1

# %%
for k in r:
  # data 불러오기
  try:
    data = pd.read_csv(Path + dir_name + str(k) + '_AST.csv')
  except:
    continue
  # df 생성
  df = pd.DataFrame(index = ast_list, columns = ast_list)
  df.fillna(0, inplace=True)
  # counting
  cnt_0()
  # csv, npy로 저장
  df.to_csv(sPath +'/csv/'+ dir_name + str(k) + '.csv')
  nparr = np.array(df)
  np.save(sPath + '/npy/'+ dir_name + str(k) + '.npy', nparr)
# Out:
# <ipython-input-12-52258ba0f88b>:9: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(0, inplace=True)
# <ipython-input-12-52258ba0f88b>:9: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(0, inplace=True)
# <ipython-input-12-52258ba0f88b>:9: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(0, inplace=True)
# ...
